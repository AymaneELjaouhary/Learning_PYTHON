# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\PC\Documents\PYTHON\data_jobs.csv")
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_location'].value_counts().head(20)
# Out:
# job_location
# Anywhere                                                     69552
# Singapore                                                    23415
# Paris, France                                                12311
# Bengaluru, Karnataka, India                                  11474
# London, UK                                                   10564
# Madrid, Spain                                                 9787
# New York, NY                                                  8165
# India                                                         7660
# United States                                                 7454
# Hong Kong                                                     7341
# Lisbon, Portugal                                              7171
# Atlanta, GA                                                   7148
# Hyderabad, Telangana, India                                   6841
# Dublin, Ireland                                               6559
# ...

# %%
#is morocoo in the data ? 
df['job_location'].isin(['Morocco']).any()
# Out:
# np.True_

# %%
#show the anywhere data
Anywhere_jobs = df[ df['job_location'] == "Anywhere"]
Anywhere_jobs = Anywhere_jobs [ Anywhere_jobs['salary_year_avg'].notna()]
Anywhere_jobs
# Out:
#               job_title_short  \
# 92              Data Engineer
# 109              Data Analyst
# 116            Data Scientist
# 571             Data Engineer
# 773             Data Engineer
# ...                       ...
# 779816  Senior Data Scientist
# 780443         Data Scientist
# 781466  Senior Data Scientist
# 782562   Senior Data Engineer
# 783761   Senior Data Engineer
#
#                                                 job_title job_location  \
# 92                Remote - Data Engineer - Permanent - W2     Anywhere
# 109                 Senior Supply Chain Analytics Analyst     Anywhere
# 116                                        Data Scientist     Anywhere
# 571     Data Engineer ETL lnformatica API SQL Engineer...     Anywhere
# 773                               Principal Data Engineer     Anywhere
# ...                                                   ...          ...
# 779816                     Senior Data Scientist (Remote)     Anywhere
# ...

# %%
Anywhere_jobs.groupby("job_title_short")['salary_year_avg'].agg (['median' , 'min' , 'max', "count" ]).sort_values(by="median" , ascending=False)
# Out:
#                              median      min       max  count
# job_title_short
# Senior Data Scientist      160000.0  45000.0  475000.0    337
# Senior Data Engineer       145000.0  35000.0  240000.0    283
# Cloud Engineer             140000.0  90000.0  204000.0      9
# Data Scientist             136000.0  30750.0  550000.0    949
# Data Engineer              130000.0  20000.0  325000.0    751
# Machine Learning Engineer  127500.0  32500.0  325000.0     40
# Software Engineer          125000.0  28000.0  225000.0     63
# Senior Data Analyst        105000.0  43031.0  185000.0    160
# Business Analyst            90000.0  16500.0  220000.0     77
# Data Analyst                86750.0  25000.0  650000.0    610
