# %%
# import Librairies
import pandas as pd 
import matplotlib.pyplot as plt

# Data & Clean
df = pd.read_csv(r'C:\Users\PC\Documents\Learning_PYTHON\data_jobs.csv')
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  str
#  1   job_title              785740 non-null  str
#  2   job_location           784696 non-null  str
#  3   job_via                785733 non-null  str
#  4   job_schedule_type      773074 non-null  str
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  str
#  7   job_posted_date        785741 non-null  datetime64[us]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  str
#  11  salary_rate            33067 non-null   str
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  str
# ...

# %%
df.sample(3)
# Do you observe that the index dosnt have a name ?
# Out:
#             job_title_short                                 job_title  \
# 609924        Data Engineer  Data Engineer - Python, ETL, SQL/MongoDB
# 161121        Data Engineer                             Data engineer
# 392919  Senior Data Analyst     Senior Product Manager Data Analytics
#
#                       job_location       job_via job_schedule_type  \
# 609924   Faridabad, Haryana, India  via LinkedIn         Full-time
# 161121  Chennai, Tamil Nadu, India    via Indeed         Full-time
# 392919                       Italy     via BeBee         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 609924               False           India 2023-02-23 12:30:55
# 161121               False           India 2023-09-08 15:49:55
# 392919               False           Italy 2023-10-28 18:13:22
#
#         job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 609924                   True                 False       India         NaN
# ...

# %%
df.index 
# This shows you the inforamtions about the index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name
# This shows you the name of the index , and because it dosnt have a name , its blank

# %%
df.index.name = 'Job index'
# Now we make a name for the index

df.index.name
# You see its not blank now !
# Out:
# 'Job index'

# %%
df.index.dtype
# This show you  the type of the index
# Out:
# dtype('int64')

# %%
# Now they are 3 index important methods to learn 
# df.reset_index ()
# df.set_index()
# df.sort_index ()

# df.reset_index () . its transforme the messy index into orginised index 
df_usa = df [ df['job_country'] == "United States"].head(5)
df_usa
# Out:
#                 job_title_short  \
# Job index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# Job index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# Job index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# ...

# %%
# You see the index are not orgonise ( 0 3 5 6 9 ...)
df_usa.reset_index( inplace= True)
df_usa

# See now how there is now index that is organised
# Out:
#    Job index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 2                                  GCP Data Engineer         Anywhere
# 3                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 4                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 1  via Diversity.com                 Full-time               False
# 2   via ZipRecruiter  Contractor and Temp work                True
# ...

# %%
# df.set_index ("column_name")
# this transforme any column you want into an index . 
df_usa.set_index ('Job index')
df_usa
# Out:
#    Job index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 2                                  GCP Data Engineer         Anywhere
# 3                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 4                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 1  via Diversity.com                 Full-time               False
# 2   via ZipRecruiter  Contractor and Temp work                True
# ...

# %%
# df.sort_index()
# I think its obious what it did
